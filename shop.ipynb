# %%
import pandas as pd

# %pwd
# Out:
# '/Users/jinyoungpark/Desktop/Projects/open-data-shop'

# %%
data1 = pd.read_csv("/Users/jinyoungpark/Desktop/Projects/open-data-shop/shop1.csv", encoding="cp949").copy()
data2 = pd.read_csv("/Users/jinyoungpark/Desktop/Projects/open-data-shop/shop2.csv", encoding="cp949").copy()
data3 = pd.read_csv("/Users/jinyoungpark/Desktop/Projects/open-data-shop/shop3.csv", encoding="cp949").copy()
data4 = pd.read_csv("/Users/jinyoungpark/Desktop/Projects/open-data-shop/shop4.csv", encoding="cp949").copy()
# Out:
# /anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (35) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (35,36) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
data1.head()
# Out:
#      상가업소번호          상호명  지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드    상권업종중분류명  \
# 0  15502838     김관선스포츠용품  NaN         D       소매       D14   운동/경기용품소매
# 1  15514817  국제컴퓨터속셈웅변학원  NaN         R    학문/교육       R07   학원-예능취미체육
# 2  15521403        더엘가커피  NaN         Q       음식       Q12      커피점/카페
# 3  15525799      더소망치과의원  NaN         S       의료       S01          병원
# 4  15538554       대우인테리어  NaN         D       소매       D07  가정/주방/인테리어
#
#   상권업종소분류코드      상권업종소분류명 표준산업분류코드    ...                         건물관리번호  \
# 0    D14A01       운동/경기용품   G47631    ...      2626010900100800012008128
# 1    R07A15         학원-웅변   P85699    ...      1168010600109890003013861
# 2    Q12A01   커피전문점/카페/다방   I56220    ...      2647010100111980000009422
# 3    S01B04          치과의원   Q86202    ...      1174010800103780000004616
# 4    D07A01  인테리어/욕실용품/커튼   G47599    ...      1126010100100230006018048
#
#                건물명                도로명주소   구우편번호    신우편번호  동정보  층정보   호정보  \
# 0           사직쌍용예가     부산광역시 동래구 사직로 80  607786  47863.0  122  NaN  1706
# 1             성창빌딩    서울특별시 강남구 도곡로 510  135501   6282.0  NaN  NaN   NaN
# 2  부산아시아드주경기장노외주차장   부산광역시 연제구 종합운동장로 7  611807  47500.0  NaN    1   NaN
# 3          웰빙메디컬빌딩  서울특별시 강동구 천호대로 1128  134843   5373.0  NaN    3   302
# 4              NaN  서울특별시 중랑구 겸재로 252-1  131811   2200.0  NaN  NaN   NaN
#
#            경도         위도
# 0  129.053851  35.197052
# 1  127.062161  37.499013
# 2  129.062034  35.191284
# 3  127.136501  37.534154
# 4  127.095579  37.589992
#
# [5 rows x 39 columns]

# %%
data2.head()
# Out:
#      상가업소번호        상호명  지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드      상권업종중분류명  \
# 0  15537336  대구80자6447  NaN         D       소매       D10       건강/미용식품
# 1  15517402   기아카클리닉평리  북부점         F    생활서비스       F14       자동차/이륜차
# 2  15512181       계양철물  NaN         D       소매       D21  철물/난방/건설자재소매
# 3  15563334   농민순대기사식당  NaN         Q       음식       Q01            한식
# 4  15554129  김미정소아청소년과  NaN         S       의료       S01            병원
#
#   상권업종소분류코드   상권업종소분류명 표준산업분류코드    ...                         건물관리번호   건물명  \
# 0    D10A01   다이어트상품판매   G47216    ...      2723012200111100000000318  그린빌1
# 1    F14A01  자동차정비/카센타      NaN    ...      2717010300106600001000196   NaN
# 2    D21A06  철물/건설자재소매   G47511    ...      2820010200103240011002417   NaN
# 3    Q01A21       기사식당   I56111    ...      3014010600100090014012779   NaN
# 4    S01B11        소아과   Q86201    ...      2729011100109310007003682   NaN
#
#                    도로명주소   구우편번호    신우편번호  동정보  층정보  호정보          경도  \
# 0       대구광역시 북구 구리로 250  702727  41418.0  102  NaN  101  128.579600
# 1      대구광역시 서구 북비산로 294  703838  41778.0  NaN  NaN  NaN  128.565334
# 2  인천광역시 남동구 경인로600번길 17  405807  21550.0  NaN    2  NaN  126.704637
# 3     대전광역시 중구 대전천서로 345  301809  34930.0  NaN  NaN  NaN  127.435506
# 4      대구광역시 달서구 용산서로 14  704936  42628.0  NaN  NaN  NaN  128.529121
#
#           위도
# 0  35.949269
# 1  35.879160
# 2  37.463836
# 3  36.321147
# 4  35.857802
#
# [5 rows x 39 columns]

# %%
data3.head()
# Out:
#      상가업소번호         상호명  지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드    상권업종중분류명  \
# 0  15502165       그린뜨게방  NaN         D       소매       D07  가정/주방/인테리어
# 1  15527046       대웅한의원  NaN         S       의료       S01          병원
# 2  15502598   광명34동굽네치킨  NaN         Q       음식       Q05      닭/오리요리
# 3  15422047        옥미식당  NaN         Q       음식       Q01          한식
# 4  15512179  경의석사성원태권도장  NaN         R    학문/교육       R07   학원-예능취미체육
#
#   상권업종소분류코드   상권업종소분류명 표준산업분류코드    ...                         건물관리번호  \
# 0    D07A12     십자수/뜨개   G47419    ...      4127310900110850000000505
# 1    S01B06        한의원   Q86203    ...      4131010300106720004002267
# 2    Q05A08  후라이드/양념치킨   I56193    ...      4121010100101580321005168
# 3    Q01A01  한식/백반/한정식   I56111    ...      4280025021005230005004911
# 4    R07A20       태권도장   P85611    ...      4161011000102510017010713
#
#        건물명                     도로명주소   구우편번호    신우편번호  동정보  층정보     호정보  \
# 0  공작한양아파트       경기도 안산시 단원구 선부로 166  425762  15234.0  NaN  NaN     NaN
# 1  세신훼미리타운       경기도 구리시 건원대로34번길 19  471841  11921.0  NaN    2     217
# 2     청산빌라           경기도 광명시 새터로 120  423858  14264.0   10  NaN     101
# 3      NaN  강원도 양구군 양구읍 양록길23번길 6-18  255804  24527.0  NaN    1     NaN
# 4    성원프라자            경기도 광주시 태봉로 51  464808  12784.0  NaN    4  403404
#
#            경도         위도
# 0  126.814011  37.340748
# 1  127.141340  37.604498
# 2  126.858374  37.477721
# 3  127.986188  38.107001
# 4  127.229655  37.388752
#
# [5 rows x 39 columns]

# %%
data4.head()
# Out:
#      상가업소번호       상호명  지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드  상권업종중분류명 상권업종소분류코드  \
# 0  15496974     건강한약국  NaN         S       의료       S02    약국/한약방    S02A02
# 1  15497649     가보세횟집  NaN         Q       음식       Q03    일식/수산물    Q03A01
# 2  15552671     대동이용원  NaN         F    생활서비스       F01   이/미용/건강    F01A04
# 3  15520915  덕산자연어린이집  NaN         R    학문/교육       R08      유아교육    R08A02
# 4  15534257    늘푸른세탁소  NaN         F    생활서비스       F02  세탁/가사서비스    F02A01
#
#   상권업종소분류명 표준산업분류코드    ...                         건물관리번호      건물명  \
# 0      한약방   G47811    ...      4415010700103160000750754      NaN
# 1       횟집   I56111    ...      4713032025101940000088487      NaN
# 2    남성미용실   S96111    ...      4812112900101240002013981  대동중앙아파트
# 3     어린이집   Q87210    ...      4812914200104460000000728  덕산해군아파트
# 4  세탁소/빨래방   S96912    ...      4812112400100840011014814      NaN
#
#                       도로명주소   구우편번호    신우편번호  동정보  층정보  호정보          경도  \
# 0           충청남도 공주시 왕릉로 35  314020  32535.0  NaN  NaN  NaN  127.112328
# 1  경상북도 경주시 양남면 효동늘밭길 19-32  780841  38216.0  NaN  NaN  NaN  129.394489
# 2      경상남도 창원시 의창구 반계로 103  641788  51373.0  NaN    3  NaN  128.616330
# 3     경상남도 창원시 진해구 진해대로 943  645762  51640.0  NaN  NaN  NaN  128.710592
# 4  경상남도 창원시 의창구 원이대로174번길 3  641813  51384.0  NaN  NaN  NaN  128.641091
#
#           위도
# 0  36.460695
# 1  35.729988
# 2  35.254795
# 3  35.144729
# 4  35.248104
#
# [5 rows x 39 columns]

# %%
#data1[c]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-a284e12437f2> in <module>()
# ----> 1 data1[c]
#
# NameError: name 'c' is not defined

# %%
#data1.columns

# %%
#data1["상호명"].head()

# %%
coffee1 = data1[["상호명","경도","위도","도로명주소"]]
coffee2 = data2[["상호명","경도","위도","도로명주소"]]
coffee3 = data3[["상호명","경도","위도","도로명주소"]]
coffee4 = data4[["상호명","경도","위도","도로명주소"]]

# %%
#df[df['A'].str.contains("hello")]
coffee1[coffee1["상호명"].str.contains("(스타벅스|이디야)", regex=True)]
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-956b19cb5a6b> in <module>()
#       1 #df[df['A'].str.contains("hello")]
# ----> 2 coffee1[coffee1["상호명"].str.contains("(스타벅스|이디야)", regex=True)]
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2677         if isinstance(key, (Series, np.ndarray, Index, list)):
#    2678             # either boolean or fancy integer index
# -> 2679             return self._getitem_array(key)
#    2680         elif isinstance(key, DataFrame):
#    2681             return self._getitem_frame(key)
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_array(self, key)
#    2704     def _getitem_array(self, key):
#    2705         # also raises Exception if object array with NA values
# -> 2706         if com.is_bool_indexer(key):
#    2707             # warning here just in case -- previously __setitem__ was
#    2708             # reindexing but __getitem__ was not; it seems more reasonable to
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/common.py in is_bool_indexer(key)
#     102             if not lib.is_bool_array(key):
#     103                 if isna(key).any():
# --> 104                     raise ValueError('cannot index with vector containing '
#     105                                      'NA / NaN values')
#     106                 return False
#
# ValueError: cannot index with vector containing NA / NaN values

# %%
coffee2 = coffee2[coffee2["상호명"].str.contains("(스타벅스|이디야)", regex=True)]
coffee2
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   """Entry point for launching an IPython kernel.
#                   상호명          경도         위도                     도로명주소
# 7896            이디야커피  126.722058  37.497635         인천광역시 부평구 부평대로 69
# 12206           이디야커피  129.317015  35.576587          울산광역시 중구 성안로 181
# 12235           이디야커피  126.842820  35.220446   광주광역시 광산구 첨단중앙로170번길 20
# 23497      스타벅스동성로중앙점  128.596677  35.867508         대구광역시 중구 동성로5길 38
# 23561           이디야커피  129.432866  35.528290      울산광역시 동구 방어진순환도로 995
# 23961       스타벅스대구법원점  128.627770  35.864537        대구광역시 수성구 동대구로 376
# 24291            스타벅스  128.533791  35.822791         대구광역시 달서구 월곡로 334
# 26688           이디야커피  126.750433  37.424215         인천광역시 남동구 서창남로 52
# 28804     스타벅스울산삼산타워점  129.336799  35.539532          울산광역시 남구 삼산로 273
# 29460     스타벅스인천청라타워돔  126.652014  37.533888  인천광역시 서구 중봉대로612번길 10-17
# 31869            스타벅스  126.914597  35.147342      광주광역시 동구 중앙로160번길 14
# 33045            스타벅스  128.520117  35.850711      대구광역시 달서구 달구벌대로 1393
# 33101           이디야커피  126.843358  35.214286       광주광역시 광산구 첨단중앙로 102
# 34751           이디야커피  126.709769  37.442142       인천광역시 남동구 선수촌공원로 37
# 34821           이디야커피  126.714258  37.442623         인천광역시 남동구 인하로 608
# 35234            스타벅스  127.438061  36.349936     대전광역시 동구 동서대로1695번길 4
# 36453            스타벅스  126.853448  35.152033        광주광역시 서구 상무자유로 173
# 36592            스타벅스  127.400514  36.399458       대전광역시 유성구 유성대로 1722
# 36751            스타벅스  126.707516  37.451560        인천광역시 남동구 남동대로 773
# 37073           이디야커피  129.357215  35.577096       울산광역시 북구 진장유통로 78-6
# 38284           이디야커피  129.350852  35.565423           울산광역시 중구 남외3길 8
# 38626            스타벅스  126.824778  35.190410         광주광역시 광산구 장신로 134
# 39427            스타벅스  127.426602  36.327945          대전광역시 중구 대종로 486
# 41540            스타벅스  126.819508  35.191134          광주광역시 광산구 장신로 85
# 42532           이디야커피  129.258763  35.548989           울산광역시 남구 신복로 36
# 43573            스타벅스  126.918247  35.146788           광주광역시 동구 서석로 43
# 44253            스타벅스  128.464258  35.859160   대구광역시 달성군 다사읍 달구벌대로 861
# 47264           이디야커피  126.719534  37.452024     인천광역시 남동구 구월남로268번길 1
# 48925           이디야커피  126.650017  37.477696          인천광역시 동구 송림로 141
# 50280           이디야커피  126.646813  37.424606      인천광역시 연수구 독배로40번길 35
# ...               ...         ...        ...                       ...
# 425542          이디야커피  126.858189  35.119800          광주광역시 서구 회재로 845
# 426334  스타벅스인천터미널사거리점  126.700869  37.445108         인천광역시 남동구 예술로 126
# 426633          이디야커피  126.755377  37.561441          인천광역시 계양구 양지로 30
# 426906          이디야커피  129.121941  35.570412     울산광역시 울주군 언양읍 읍성로 123
# 427156          이디야커피  126.852385  35.126857      광주광역시 서구 화개중앙로87번길 6
# 427157          이디야커피  129.289076  35.410658  울산광역시 울주군 온양읍 보곡1길 30-10
# 431621       이디야인하대병원  126.634148  37.458844           인천광역시 중구 인항로 27
# 431787   이디야구월아시아드선수촌  126.714258  37.442650         인천광역시 남동구 인하로 608
# 432368          이디야커피  126.673070  37.516007          인천광역시 서구 가정로 350
# 432983       이디야울산문수로  129.296061  35.533866          울산광역시 남구 문수로 390
# 433620          이디야커피  129.265505  35.552001     울산광역시 남구 북부순환도로19번길 4
# 436091          이디야커피  126.684388  37.493121   인천광역시 서구 장고개로337번길 18-3
# 436241           스타벅스  128.545210  35.824029         대구광역시 달서구 월배로 315
# 436379           스타벅스  128.615879  35.826139          대구광역시 수성구 용학로 56
# 436497           스타벅스  126.644266  37.384805        인천광역시 연수구 하모니로 136
# 437675          이디야커피  129.344967  35.545958          울산광역시 남구 정동로 136
# 437694          이디야커피  128.628726  35.879098         대구광역시 동구 동대구로 550
# 437957          이디야커피  126.737806  37.519447         인천광역시 부평구 후정동로 21
# 438742           스타벅스  128.596148  35.879651         대구광역시 북구 중앙대로 526
# 439152          이디야커피  129.348385  35.553833         울산광역시 중구 내황14길 50
# 440384          이디야커피  127.257648  36.490986  세종특별자치시 세종특별자치시 나성북1로 12
# 440441           스타벅스  128.620323  35.853823         대구광역시 수성구 명덕로 460
# 440720           스타벅스  127.378241  36.298368          대전광역시 서구 복수남로 28
# 440845          이디야커피  128.609675  35.906289         대구광역시 북구 유통단지로 60
# 441122          이디야커피  126.670814  37.527154        인천광역시 서구 봉오재3로 100
# 441357          이디야커피  126.487611  37.745503    인천광역시 강화군 강화읍 강화대로 392
# 441781          이디야커피  129.320799  35.521421        울산광역시 남구 신선로74번길 5
# 441853          이디야커피  126.955901  35.133868       광주광역시 동구 증심사길30번길 5
# 442429           스타벅스  126.879927  35.152263      광주광역시 서구 군분로245번길 12
# 442704          이디야커피  126.644363  37.537188        인천광역시 서구 청라커낼로 321
#
# [530 rows x 4 columns]

# %%
coffee3[coffee3["상호명"].str.contains("(스타벅스|이디야)", regex=True)]
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   """Entry point for launching an IPython kernel.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-9fd0b27ac6c6> in <module>()
# ----> 1 coffee3[coffee3["상호명"].str.contains("(스타벅스|이디야)", regex=True)]
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2677         if isinstance(key, (Series, np.ndarray, Index, list)):
#    2678             # either boolean or fancy integer index
# -> 2679             return self._getitem_array(key)
#    2680         elif isinstance(key, DataFrame):
#    2681             return self._getitem_frame(key)
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_array(self, key)
#    2704     def _getitem_array(self, key):
#    2705         # also raises Exception if object array with NA values
# -> 2706         if com.is_bool_indexer(key):
#    2707             # warning here just in case -- previously __setitem__ was
#    2708             # reindexing but __getitem__ was not; it seems more reasonable to
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/common.py in is_bool_indexer(key)
#     102             if not lib.is_bool_array(key):
#     103                 if isna(key).any():
# --> 104                     raise ValueError('cannot index with vector containing '
#     105                                      'NA / NaN values')
#     106                 return False
#
# ValueError: cannot index with vector containing NA / NaN values

# %%
coffee4 = coffee4[coffee4["상호명"].str.contains("(스타벅스|이디야)", regex=True)]
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   """Entry point for launching an IPython kernel.

# %%
#result = pd.concat([df1, df4], axis=1, join='inner')
coffee = coffee2.append(coffee4)
coffee
coffee['브랜드명'] = ''
coffee.loc[coffee['상호명'].str.contains('스타벅스'), '브랜드명'] = '스타벅스'
coffee.loc[coffee['상호명'].str.contains('이디야'), '브랜드명'] = '이디야'

# %%
# starbucks = coffee.loc[coffee["상호명"].str.contains("스타벅스")]
# ediya = coffee.loc[coffee["상호명"].str.contains("이디야")]
                       
# df_seoul.loc[
#     df_seoul['상호명'].str.contains('뚜레쥬르|파리(바게|크라상)') &
#     (~df_bread['상호명'].str.contains('파스쿠찌|잠바주스'))

# %%
import folium

map_korea = folium.Map(location=[35.9078, 127.7669],
                    zoom_start = 7) # Uses lat then lon. The bigger the zoom number, the closer in you get
map_korea # Calls the map to display

#source :https://www.kaggle.com/daveianhickey/how-to-folium-for-maps-heatmaps-time-analysis
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#map_korea = folium.Map(location=[51.5074, 0.1278],
#                         tiles = "Stamen Toner",
#                         zoom_start = 12)
# # 'width=int' and 'height=int' can also be added to the map

#folium.Marker([51.5079, 0.0877], popup='London Bridge').add_to(map_hooray)
#map_hooray

# for n in coffee.index:
#     # 팝업에 들어갈 텍스트를 지정해 줍니다.
#     popup_name = coffee['상호명'][n] + ' - ' + coffee['도로명주소'][n]
#     # 브랜드명에 따라 아이콘 색상을 달리해서 찍어줍니다.
#     if coffee['상호명'][n] is '이디야' :
#         icon_color = 'green'
#     if coffee['상호명'][n] is '스타벅스':
#         icon_color = 'blue'
#     else:
#         pass
    
#     folium.Marker([coffee['위도'][n], coffee['경도'][n]], 
#                   popup=popup_name, 
#                   icon=folium.Icon(color=icon_color)).add_to(map)

# map

# %%
starbucks['위도'] = starbucks['위도'].astype(float)
starbucks['경도'] = starbucks['경도'].astype(float)
ediya['위도'] = ediya['위도'].astype(float)
ediya['경도'] = ediya['경도'].astype(float)
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
import warnings
warnings.filterwarnings('ignore')

from plotnine import *

(ggplot(coffee)
 + aes(x='경도', y='위도', color='브랜드명')
 + geom_point()
 + theme(text=element_text(family='NanumBarunGothic'))
 + scale_fill_gradient(low = 'blue', high = 'green') 
)
# Out:
# <ggplot: (-9223372036495963795)>

# %%
#map_korea = folium.Map(location=[35.9078, 127.7669],zoom_start = 7)

for n in coffee.index:
    # 팝업에 들어갈 텍스트를 지정해 줍니다.
    popup_name = coffee['브랜드명'][n] + ' - ' + coffee['도로명주소'][n]
    # 브랜드명에 따라 아이콘 색상을 달리해서 찍어줍니다.
    if coffee['브랜드명'][n] == '스타벅스' :
        icon_color = 'pink'
    if coffee['브랜드명'][n] == '이디야':
        icon_color = 'blue'    
    else:
        pass
    
    folium.Marker([coffee['위도'][n], coffee['경도'][n]], 
                  popup=popup_name, 
                  icon=folium.Icon(color=icon_color)).add_to(map_korea)

for each in coffee[0:100].iterrows():
    map_korea.simple_marker(
        location = [each[1]['Y'],each[1]['X']],
        clustered_marker = True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-35-56462ad76b8a> in <module>()
#      17
#      18 for each in coffee[0:100].iterrows():
# ---> 19     map_korea.simple_marker(
#      20         location = [each[1]['Y'],each[1]['X']],
#      21         clustered_marker = True)
#
# AttributeError: 'Map' object has no attribute 'simple_marker'

# %%
display(map_korea)
